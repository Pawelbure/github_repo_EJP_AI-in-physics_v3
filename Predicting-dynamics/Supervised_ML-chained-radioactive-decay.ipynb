# %% [markdown]
# # Radioactive Decay Chain Modeling with PINNs
#
# This notebook models a simple radioactive decay chain using Physics-Informed Neural Networks (PINNs).
# The system of equations is:
#
# \begin{align}
# \frac{dN_1}{dt} &= -\lambda_1 N_1 \\
# \frac{dN_2}{dt} &= \lambda_1 N_1 - \lambda_2 N_2 \\
# \frac{dN_3}{dt} &= \lambda_2 N_2
# \end{align}
#
# This represents a decay sequence: \( N_1 \rightarrow N_2 \rightarrow N_3 \)
#
# We will define the system, generate synthetic data, and train a neural network to approximate the dynamics while enforcing physical constraints via PINNs.

# %% [markdown]
# ## Load packages and set seed

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
from torch.autograd import grad

seed = 42

# %% [markdown]
# ## Simulate data

# %%
np.random.seed(seed)

# Decay constants
lambda1 = 0.5
lambda2 = 0.3

# Time points
t_start = 0
t_end = 3
prediction_time = 3 # length of prediction

t = np.linspace(t_start, t_end, 1000)
dt = t[1] - t[0]

# Initial conditions
N1_0, N2_0, N3_0 = .8, .1, .5

# Initialize arrays
N1, N2, N3 = np.zeros_like(t), np.zeros_like(t), np.zeros_like(t)
N1[0], N2[0], N3[0] = N1_0, N2_0, N3_0

# Euler integration
for i in range(1, len(t)):
    dN1 = -lambda1 * N1[i-1]
    dN2 = lambda1 * N1[i-1] - lambda2 * N2[i-1]
    dN3 = lambda2 * N2[i-1]
    N1[i] = N1[i-1] + dN1 * dt
    N2[i] = N2[i-1] + dN2 * dt
    N3[i] = N3[i-1] + dN3 * dt

# Tensors for full supervised data and evaluation
t_tensor = torch.tensor(t, dtype=torch.float32).view(-1, 1)
N_data = torch.tensor(np.stack([N1, N2, N3], axis=1), dtype=torch.float32)

# Collocation points (used by PINN for residual loss)
n_collocation = 4
indices = np.random.choice(len(t), n_collocation, replace=False)
indices = np.sort(indices)
t_col = torch.tensor(t[indices], dtype=torch.float32).view(-1, 1).requires_grad_(True)
N_col = N_data[indices]

# Plot simulated data and collocation points
plt.figure(figsize=(10, 6))
plt.plot(t, N1, 'r', label='N1')
plt.plot(t, N2, 'g', label='N2')
plt.plot(t, N3, 'b', label='N3')
plt.scatter(t[indices], N1[indices], color='k', s=10, label='Collocation (N1)')
plt.scatter(t[indices], N2[indices], color='c', s=10, label='Collocation (N2)')
plt.scatter(t[indices], N3[indices], color='m', s=10, label='Collocation (N3)')
plt.title("Decay Chain Simulation with Collocation Points")
plt.xlabel("Time")
plt.ylabel("Population")
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Define ANN

# %%
class MLP(nn.Module):
    def __init__(self):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(1, 8), nn.Tanh(),
            nn.Linear(8, 8), nn.Tanh(),
            nn.Linear(8, 3)
        )

    def forward(self, t):
        return self.net(t)

def compute_derivatives(y, t):
    dy = grad(y, t, torch.ones_like(y), create_graph=True)[0]
    return dy

# %% [markdown]
# ## Direct solution model

# %%
# hyperparameters:
lr = 2e-4
epochs = 7000

# %%
torch.manual_seed(seed)
model_direct = MLP()
optimizer = torch.optim.Adam(model_direct.parameters(), lr=lr)

# Only use collocation points for training
t_col_supervised = t_tensor[indices]  # detached input without gradients
N_col_supervised = N_data[indices]

for epoch in range(epochs):
    optimizer.zero_grad()
    pred = model_direct(t_col_supervised)
    loss = ((pred - N_col_supervised)**2).mean()
    loss.backward()
    optimizer.step()
    if epoch % 50 == 0:
        print(f"[Direct ANN - Collocation Only] Epoch {epoch}: Loss = {loss.item():.6f}")
pred_direct = model_direct(t_tensor).detach().numpy()
# Out:
# [Direct ANN - Collocation Only] Epoch 0: Loss = 0.444474
# [Direct ANN - Collocation Only] Epoch 50: Loss = 0.335540
# [Direct ANN - Collocation Only] Epoch 100: Loss = 0.247837
# [Direct ANN - Collocation Only] Epoch 150: Loss = 0.176651
# [Direct ANN - Collocation Only] Epoch 200: Loss = 0.120474
# [Direct ANN - Collocation Only] Epoch 250: Loss = 0.078493
# [Direct ANN - Collocation Only] Epoch 300: Loss = 0.049082
# [Direct ANN - Collocation Only] Epoch 350: Loss = 0.029743
# [Direct ANN - Collocation Only] Epoch 400: Loss = 0.017693
# [Direct ANN - Collocation Only] Epoch 450: Loss = 0.010468
# [Direct ANN - Collocation Only] Epoch 500: Loss = 0.006247
# [Direct ANN - Collocation Only] Epoch 550: Loss = 0.003831
# [Direct ANN - Collocation Only] Epoch 600: Loss = 0.002478
# [Direct ANN - Collocation Only] Epoch 650: Loss = 0.001744
# [Direct ANN - Collocation Only] Epoch 700: Loss = 0.001358
# [Direct ANN - Collocation Only] Epoch 750: Loss = 0.001162
# [Direct ANN - Collocation Only] Epoch 800: Loss = 0.001065
# [Direct ANN - Collocation Only] Epoch 850: Loss = 0.001016
# [Direct ANN - Collocation Only] Epoch 900: Loss = 0.000991
# [Direct ANN - Collocation Only] Epoch 950: Loss = 0.000976
# [Direct ANN - Collocation Only] Epoch 1000: Loss = 0.000965
# [Direct ANN - Collocation Only] Epoch 1050: Loss = 0.000956
# [Direct ANN - Collocation Only] Epoch 1100: Loss = 0.000947
# [Direct ANN - Collocation Only] Epoch 1150: Loss = 0.000938
# [Direct ANN - Collocation Only] Epoch 1200: Loss = 0.000929
# [Direct ANN - Collocation Only] Epoch 1250: Loss = 0.000920
# [Direct ANN - Collocation Only] Epoch 1300: Loss = 0.000911
# [Direct ANN - Collocation Only] Epoch 1350: Loss = 0.000901
# [Direct ANN - Collocation Only] Epoch 1400: Loss = 0.000892
# [Direct ANN - Collocation Only] Epoch 1450: Loss = 0.000882
# [Direct ANN - Collocation Only] Epoch 1500: Loss = 0.000872
# [Direct ANN - Collocation Only] Epoch 1550: Loss = 0.000862
# [Direct ANN - Collocation Only] Epoch 1600: Loss = 0.000851
# [Direct ANN - Collocation Only] Epoch 1650: Loss = 0.000841
# [Direct ANN - Collocation Only] Epoch 1700: Loss = 0.000830
# [Direct ANN - Collocation Only] Epoch 1750: Loss = 0.000819
# [Direct ANN - Collocation Only] Epoch 1800: Loss = 0.000808
# [Direct ANN - Collocation Only] Epoch 1850: Loss = 0.000797
# [Direct ANN - Collocation Only] Epoch 1900: Loss = 0.000785
# [Direct ANN - Collocation Only] Epoch 1950: Loss = 0.000774
# [Direct ANN - Collocation Only] Epoch 2000: Loss = 0.000762
# [Direct ANN - Collocation Only] Epoch 2050: Loss = 0.000751
# [Direct ANN - Collocation Only] Epoch 2100: Loss = 0.000739
# [Direct ANN - Collocation Only] Epoch 2150: Loss = 0.000727
# [Direct ANN - Collocation Only] Epoch 2200: Loss = 0.000715
# [Direct ANN - Collocation Only] Epoch 2250: Loss = 0.000702
# [Direct ANN - Collocation Only] Epoch 2300: Loss = 0.000690
# [Direct ANN - Collocation Only] Epoch 2350: Loss = 0.000678
# [Direct ANN - Collocation Only] Epoch 2400: Loss = 0.000665
# [Direct ANN - Collocation Only] Epoch 2450: Loss = 0.000653
# [Direct ANN - Collocation Only] Epoch 2500: Loss = 0.000640
# [Direct ANN - Collocation Only] Epoch 2550: Loss = 0.000627
# [Direct ANN - Collocation Only] Epoch 2600: Loss = 0.000615
# [Direct ANN - Collocation Only] Epoch 2650: Loss = 0.000602
# [Direct ANN - Collocation Only] Epoch 2700: Loss = 0.000589
# [Direct ANN - Collocation Only] Epoch 2750: Loss = 0.000576
# [Direct ANN - Collocation Only] Epoch 2800: Loss = 0.000563
# [Direct ANN - Collocation Only] Epoch 2850: Loss = 0.000550
# [Direct ANN - Collocation Only] Epoch 2900: Loss = 0.000537
# [Direct ANN - Collocation Only] Epoch 2950: Loss = 0.000524
# [Direct ANN - Collocation Only] Epoch 3000: Loss = 0.000510
# [Direct ANN - Collocation Only] Epoch 3050: Loss = 0.000497
# [Direct ANN - Collocation Only] Epoch 3100: Loss = 0.000484
# [Direct ANN - Collocation Only] Epoch 3150: Loss = 0.000471
# [Direct ANN - Collocation Only] Epoch 3200: Loss = 0.000458
# [Direct ANN - Collocation Only] Epoch 3250: Loss = 0.000444
# [Direct ANN - Collocation Only] Epoch 3300: Loss = 0.000431
# [Direct ANN - Collocation Only] Epoch 3350: Loss = 0.000418
# [Direct ANN - Collocation Only] Epoch 3400: Loss = 0.000405
# [Direct ANN - Collocation Only] Epoch 3450: Loss = 0.000392
# [Direct ANN - Collocation Only] Epoch 3500: Loss = 0.000379
# [Direct ANN - Collocation Only] Epoch 3550: Loss = 0.000366
# [Direct ANN - Collocation Only] Epoch 3600: Loss = 0.000353
# [Direct ANN - Collocation Only] Epoch 3650: Loss = 0.000340
# [Direct ANN - Collocation Only] Epoch 3700: Loss = 0.000327
# [Direct ANN - Collocation Only] Epoch 3750: Loss = 0.000314
# [Direct ANN - Collocation Only] Epoch 3800: Loss = 0.000301
# [Direct ANN - Collocation Only] Epoch 3850: Loss = 0.000288
# [Direct ANN - Collocation Only] Epoch 3900: Loss = 0.000276
# [Direct ANN - Collocation Only] Epoch 3950: Loss = 0.000264
# [Direct ANN - Collocation Only] Epoch 4000: Loss = 0.000251
# [Direct ANN - Collocation Only] Epoch 4050: Loss = 0.000239
# [Direct ANN - Collocation Only] Epoch 4100: Loss = 0.000227
# [Direct ANN - Collocation Only] Epoch 4150: Loss = 0.000216
# [Direct ANN - Collocation Only] Epoch 4200: Loss = 0.000204
# [Direct ANN - Collocation Only] Epoch 4250: Loss = 0.000193
# [Direct ANN - Collocation Only] Epoch 4300: Loss = 0.000182
# [Direct ANN - Collocation Only] Epoch 4350: Loss = 0.000171
# [Direct ANN - Collocation Only] Epoch 4400: Loss = 0.000160
# [Direct ANN - Collocation Only] Epoch 4450: Loss = 0.000150
# [Direct ANN - Collocation Only] Epoch 4500: Loss = 0.000140
# [Direct ANN - Collocation Only] Epoch 4550: Loss = 0.000131
# [Direct ANN - Collocation Only] Epoch 4600: Loss = 0.000122
# [Direct ANN - Collocation Only] Epoch 4650: Loss = 0.000113
# [Direct ANN - Collocation Only] Epoch 4700: Loss = 0.000104
# [Direct ANN - Collocation Only] Epoch 4750: Loss = 0.000096
# [Direct ANN - Collocation Only] Epoch 4800: Loss = 0.000089
# [Direct ANN - Collocation Only] Epoch 4850: Loss = 0.000081
# [Direct ANN - Collocation Only] Epoch 4900: Loss = 0.000075
# [Direct ANN - Collocation Only] Epoch 4950: Loss = 0.000068
# [Direct ANN - Collocation Only] Epoch 5000: Loss = 0.000062
# [Direct ANN - Collocation Only] Epoch 5050: Loss = 0.000057
# [Direct ANN - Collocation Only] Epoch 5100: Loss = 0.000051
# [Direct ANN - Collocation Only] Epoch 5150: Loss = 0.000047
# [Direct ANN - Collocation Only] Epoch 5200: Loss = 0.000042
# [Direct ANN - Collocation Only] Epoch 5250: Loss = 0.000038
# [Direct ANN - Collocation Only] Epoch 5300: Loss = 0.000035
# [Direct ANN - Collocation Only] Epoch 5350: Loss = 0.000032
# [Direct ANN - Collocation Only] Epoch 5400: Loss = 0.000029
# [Direct ANN - Collocation Only] Epoch 5450: Loss = 0.000026
# [Direct ANN - Collocation Only] Epoch 5500: Loss = 0.000024
# [Direct ANN - Collocation Only] Epoch 5550: Loss = 0.000022
# [Direct ANN - Collocation Only] Epoch 5600: Loss = 0.000020
# [Direct ANN - Collocation Only] Epoch 5650: Loss = 0.000018
# [Direct ANN - Collocation Only] Epoch 5700: Loss = 0.000017
# [Direct ANN - Collocation Only] Epoch 5750: Loss = 0.000016
# [Direct ANN - Collocation Only] Epoch 5800: Loss = 0.000015
# [Direct ANN - Collocation Only] Epoch 5850: Loss = 0.000014
# [Direct ANN - Collocation Only] Epoch 5900: Loss = 0.000013
# [Direct ANN - Collocation Only] Epoch 5950: Loss = 0.000012
# [Direct ANN - Collocation Only] Epoch 6000: Loss = 0.000011
# [Direct ANN - Collocation Only] Epoch 6050: Loss = 0.000011
# [Direct ANN - Collocation Only] Epoch 6100: Loss = 0.000011
# [Direct ANN - Collocation Only] Epoch 6150: Loss = 0.000010
# [Direct ANN - Collocation Only] Epoch 6200: Loss = 0.000010
# [Direct ANN - Collocation Only] Epoch 6250: Loss = 0.000009
# [Direct ANN - Collocation Only] Epoch 6300: Loss = 0.000009
# [Direct ANN - Collocation Only] Epoch 6350: Loss = 0.000009
# [Direct ANN - Collocation Only] Epoch 6400: Loss = 0.000009
# [Direct ANN - Collocation Only] Epoch 6450: Loss = 0.000009
# [Direct ANN - Collocation Only] Epoch 6500: Loss = 0.000008
# [Direct ANN - Collocation Only] Epoch 6550: Loss = 0.000008
# [Direct ANN - Collocation Only] Epoch 6600: Loss = 0.000008
# [Direct ANN - Collocation Only] Epoch 6650: Loss = 0.000008
# [Direct ANN - Collocation Only] Epoch 6700: Loss = 0.000008
# [Direct ANN - Collocation Only] Epoch 6750: Loss = 0.000008
# [Direct ANN - Collocation Only] Epoch 6800: Loss = 0.000008
# [Direct ANN - Collocation Only] Epoch 6850: Loss = 0.000008
# [Direct ANN - Collocation Only] Epoch 6900: Loss = 0.000008
# [Direct ANN - Collocation Only] Epoch 6950: Loss = 0.000008

# %% [markdown]
# ## PINN

# %%
torch.manual_seed(seed)
model_pinn = MLP()
optimizer = torch.optim.Adam(model_pinn.parameters(), lr=lr)

lambda1_tensor = torch.tensor(lambda1, dtype=torch.float32)
lambda2_tensor = torch.tensor(lambda2, dtype=torch.float32)

for epoch in range(epochs):
    optimizer.zero_grad()

    # Residuals on collocation points
    pred_col = model_pinn(t_col)
    N1_pred, N2_pred, N3_pred = pred_col[:, 0:1], pred_col[:, 1:2], pred_col[:, 2:3]

    dN1_dt = compute_derivatives(N1_pred, t_col)
    dN2_dt = compute_derivatives(N2_pred, t_col)
    dN3_dt = compute_derivatives(N3_pred, t_col)

    res1 = dN1_dt + lambda1_tensor * N1_pred
    res2 = dN2_dt - (lambda1_tensor * N1_pred - lambda2_tensor * N2_pred)
    res3 = dN3_dt - lambda2_tensor * N2_pred

    loss_ode = (res1**2).mean() + (res2**2).mean() + (res3**2).mean()

    # Supervised fit on full data
    pred_all = model_pinn(t_tensor)
    loss_data = ((pred_all - N_data)**2).mean()

    loss = loss_ode + loss_data
    loss.backward()
    optimizer.step()

    if epoch % 50 == 0:
        print(f"[PINN] Epoch {epoch}: Loss = {loss.item():.6f}")
pred_pinn = model_pinn(t_tensor).detach().numpy()
# Out:
# [PINN] Epoch 0: Loss = 0.461462
# [PINN] Epoch 50: Loss = 0.366777
# [PINN] Epoch 100: Loss = 0.291426
# [PINN] Epoch 150: Loss = 0.230310
# [PINN] Epoch 200: Loss = 0.180144
# [PINN] Epoch 250: Loss = 0.139362
# [PINN] Epoch 300: Loss = 0.106960
# [PINN] Epoch 350: Loss = 0.081927
# [PINN] Epoch 400: Loss = 0.063106
# [PINN] Epoch 450: Loss = 0.049246
# [PINN] Epoch 500: Loss = 0.039129
# [PINN] Epoch 550: Loss = 0.031704
# [PINN] Epoch 600: Loss = 0.026157
# [PINN] Epoch 650: Loss = 0.021919
# [PINN] Epoch 700: Loss = 0.018613
# [PINN] Epoch 750: Loss = 0.015994
# [PINN] Epoch 800: Loss = 0.013895
# [PINN] Epoch 850: Loss = 0.012191
# [PINN] Epoch 900: Loss = 0.010790
# [PINN] Epoch 950: Loss = 0.009619
# [PINN] Epoch 1000: Loss = 0.008625
# [PINN] Epoch 1050: Loss = 0.007768
# [PINN] Epoch 1100: Loss = 0.007022
# [PINN] Epoch 1150: Loss = 0.006370
# [PINN] Epoch 1200: Loss = 0.005798
# [PINN] Epoch 1250: Loss = 0.005297
# [PINN] Epoch 1300: Loss = 0.004857
# [PINN] Epoch 1350: Loss = 0.004473
# [PINN] Epoch 1400: Loss = 0.004138
# [PINN] Epoch 1450: Loss = 0.003846
# [PINN] Epoch 1500: Loss = 0.003590
# [PINN] Epoch 1550: Loss = 0.003367
# [PINN] Epoch 1600: Loss = 0.003170
# [PINN] Epoch 1650: Loss = 0.002997
# [PINN] Epoch 1700: Loss = 0.002842
# [PINN] Epoch 1750: Loss = 0.002704
# [PINN] Epoch 1800: Loss = 0.002579
# [PINN] Epoch 1850: Loss = 0.002466
# [PINN] Epoch 1900: Loss = 0.002362
# [PINN] Epoch 1950: Loss = 0.002266
# [PINN] Epoch 2000: Loss = 0.002177
# [PINN] Epoch 2050: Loss = 0.002094
# [PINN] Epoch 2100: Loss = 0.002017
# [PINN] Epoch 2150: Loss = 0.001943
# [PINN] Epoch 2200: Loss = 0.001874
# [PINN] Epoch 2250: Loss = 0.001809
# [PINN] Epoch 2300: Loss = 0.001746
# [PINN] Epoch 2350: Loss = 0.001686
# [PINN] Epoch 2400: Loss = 0.001629
# [PINN] Epoch 2450: Loss = 0.001573
# [PINN] Epoch 2500: Loss = 0.001520
# [PINN] Epoch 2550: Loss = 0.001468
# [PINN] Epoch 2600: Loss = 0.001418
# [PINN] Epoch 2650: Loss = 0.001370
# [PINN] Epoch 2700: Loss = 0.001323
# [PINN] Epoch 2750: Loss = 0.001277
# [PINN] Epoch 2800: Loss = 0.001232
# [PINN] Epoch 2850: Loss = 0.001188
# [PINN] Epoch 2900: Loss = 0.001145
# [PINN] Epoch 2950: Loss = 0.001102
# [PINN] Epoch 3000: Loss = 0.001061
# [PINN] Epoch 3050: Loss = 0.001020
# [PINN] Epoch 3100: Loss = 0.000980
# [PINN] Epoch 3150: Loss = 0.000941
# [PINN] Epoch 3200: Loss = 0.000903
# [PINN] Epoch 3250: Loss = 0.000865
# [PINN] Epoch 3300: Loss = 0.000827
# [PINN] Epoch 3350: Loss = 0.000791
# [PINN] Epoch 3400: Loss = 0.000755
# [PINN] Epoch 3450: Loss = 0.000719
# [PINN] Epoch 3500: Loss = 0.000685
# [PINN] Epoch 3550: Loss = 0.000651
# [PINN] Epoch 3600: Loss = 0.000618
# [PINN] Epoch 3650: Loss = 0.000585
# [PINN] Epoch 3700: Loss = 0.000554
# [PINN] Epoch 3750: Loss = 0.000523
# [PINN] Epoch 3800: Loss = 0.000493
# [PINN] Epoch 3850: Loss = 0.000464
# [PINN] Epoch 3900: Loss = 0.000436
# [PINN] Epoch 3950: Loss = 0.000409
# [PINN] Epoch 4000: Loss = 0.000383
# [PINN] Epoch 4050: Loss = 0.000358
# [PINN] Epoch 4100: Loss = 0.000334
# [PINN] Epoch 4150: Loss = 0.000311
# [PINN] Epoch 4200: Loss = 0.000290
# [PINN] Epoch 4250: Loss = 0.000270
# [PINN] Epoch 4300: Loss = 0.000250
# [PINN] Epoch 4350: Loss = 0.000232
# [PINN] Epoch 4400: Loss = 0.000216
# [PINN] Epoch 4450: Loss = 0.000200
# [PINN] Epoch 4500: Loss = 0.000185
# [PINN] Epoch 4550: Loss = 0.000172
# [PINN] Epoch 4600: Loss = 0.000160
# [PINN] Epoch 4650: Loss = 0.000148
# [PINN] Epoch 4700: Loss = 0.000138
# [PINN] Epoch 4750: Loss = 0.000128
# [PINN] Epoch 4800: Loss = 0.000120
# [PINN] Epoch 4850: Loss = 0.000112
# [PINN] Epoch 4900: Loss = 0.000105
# [PINN] Epoch 4950: Loss = 0.000099
# [PINN] Epoch 5000: Loss = 0.000093
# [PINN] Epoch 5050: Loss = 0.000088
# [PINN] Epoch 5100: Loss = 0.000083
# [PINN] Epoch 5150: Loss = 0.000079
# [PINN] Epoch 5200: Loss = 0.000075
# [PINN] Epoch 5250: Loss = 0.000072
# [PINN] Epoch 5300: Loss = 0.000069
# [PINN] Epoch 5350: Loss = 0.000066
# [PINN] Epoch 5400: Loss = 0.000063
# [PINN] Epoch 5450: Loss = 0.000061
# [PINN] Epoch 5500: Loss = 0.000059
# [PINN] Epoch 5550: Loss = 0.000057
# [PINN] Epoch 5600: Loss = 0.000055
# [PINN] Epoch 5650: Loss = 0.000054
# [PINN] Epoch 5700: Loss = 0.000052
# [PINN] Epoch 5750: Loss = 0.000050
# [PINN] Epoch 5800: Loss = 0.000049
# [PINN] Epoch 5850: Loss = 0.000048
# [PINN] Epoch 5900: Loss = 0.000046
# [PINN] Epoch 5950: Loss = 0.000045
# [PINN] Epoch 6000: Loss = 0.000044
# [PINN] Epoch 6050: Loss = 0.000043
# [PINN] Epoch 6100: Loss = 0.000042
# [PINN] Epoch 6150: Loss = 0.000041
# [PINN] Epoch 6200: Loss = 0.000039
# [PINN] Epoch 6250: Loss = 0.000038
# [PINN] Epoch 6300: Loss = 0.000037
# [PINN] Epoch 6350: Loss = 0.000037
# [PINN] Epoch 6400: Loss = 0.000036
# [PINN] Epoch 6450: Loss = 0.000035
# [PINN] Epoch 6500: Loss = 0.000034
# [PINN] Epoch 6550: Loss = 0.000033
# [PINN] Epoch 6600: Loss = 0.000032
# [PINN] Epoch 6650: Loss = 0.000031
# [PINN] Epoch 6700: Loss = 0.000031
# [PINN] Epoch 6750: Loss = 0.000030
# [PINN] Epoch 6800: Loss = 0.000029
# [PINN] Epoch 6850: Loss = 0.000028
# [PINN] Epoch 6900: Loss = 0.000028
# [PINN] Epoch 6950: Loss = 0.000027

# %% [markdown]
# ## Evaluate model and predict time series

# %%
# Compute final losses
# Direct model
pred_direct_all = torch.tensor(pred_direct, dtype=torch.float32)
L_direct_mse = ((pred_direct_all - N_data)**2).mean().item()
L_direct_total = L_direct_mse

# PINN model
pred_pinn_all = torch.tensor(pred_pinn, dtype=torch.float32)
L_pinn_mse = ((pred_pinn_all - N_data)**2).mean().item()

pred_col = model_pinn(t_col)
N1_pred, N2_pred, N3_pred = pred_col[:, 0:1], pred_col[:, 1:2], pred_col[:, 2:3]
dN1_dt = compute_derivatives(N1_pred, t_col)
dN2_dt = compute_derivatives(N2_pred, t_col)
dN3_dt = compute_derivatives(N3_pred, t_col)
res1 = dN1_dt + lambda1 * N1_pred
res2 = dN2_dt - (lambda1 * N1_pred - lambda2 * N2_pred)
res3 = dN3_dt - lambda2 * N2_pred
L_pinn_ode = (res1**2).mean().item() + (res2**2).mean().item() + (res3**2).mean().item()
L_pinn_total = L_pinn_mse + L_pinn_ode

# %%
# Generate extrapolated time and predictions
t_extra = np.linspace(t_end, t_end+prediction_time, 200)
t_extra_tensor = torch.tensor(t_extra, dtype=torch.float32).view(-1, 1)

pred_direct_extra = model_direct(t_extra_tensor).detach().numpy()
pred_pinn_extra = model_pinn(t_extra_tensor).detach().numpy()

# Combine time and predictions
t_total = np.concatenate([t, t_extra])
pred_direct_total = np.concatenate([pred_direct, pred_direct_extra])
pred_pinn_total = np.concatenate([pred_pinn, pred_pinn_extra])


# Euler simulation for extrapolated range [t_end, t_end + prediction_time]
t_extra = np.linspace(t_end, t_end + prediction_time, 200)
dt_extra = t_extra[1] - t_extra[0]

# Initialize with last known values from training interval
N1_extra = np.zeros_like(t_extra)
N2_extra = np.zeros_like(t_extra)
N3_extra = np.zeros_like(t_extra)

N1_extra[0] = N1[-1]
N2_extra[0] = N2[-1]
N3_extra[0] = N3[-1]

for i in range(1, len(t_extra)):
    dN1 = -lambda1 * N1_extra[i-1]
    dN2 = lambda1 * N1_extra[i-1] - lambda2 * N2_extra[i-1]
    dN3 = lambda2 * N2_extra[i-1]
    N1_extra[i] = N1_extra[i-1] + dN1 * dt_extra
    N2_extra[i] = N2_extra[i-1] + dN2 * dt_extra
    N3_extra[i] = N3_extra[i-1] + dN3 * dt_extra

# Concatenate to get full solution for plotting
t_total = np.concatenate([t, t_extra])
N1_true_total = np.concatenate([N1, N1_extra])
N2_true_total = np.concatenate([N2, N2_extra])
N3_true_total = np.concatenate([N3, N3_extra])

# %%
# Calculate prediction error
# Compute extrapolation errors (only for extrapolated range)
true_extra = np.stack([N1_extra, N2_extra, N3_extra], axis=1)

# Prediction error for Direct ANN in extrapolated region
error_direct = ((pred_direct_extra - true_extra) ** 2).mean()

# Prediction error for PINN in extrapolated region
error_pinn = ((pred_pinn_extra - true_extra) ** 2).mean()

# %%
# Plot
fig, axs = plt.subplots(2, 1, figsize=(8, 10), sharex=True)

for ax in axs:
    ax.axvspan(t_end, t_end+prediction_time, color='yellow', alpha=0.2, label='Extrapolation Region')

# Top: Direct ANN
axs[0].plot(t_total, N1_true_total, 'r', label='N1 True')
axs[0].plot(t_total, N2_true_total, 'g', label='N2 True')
axs[0].plot(t_total, N3_true_total, 'b', label='N3 True')
axs[0].plot(t_total, pred_direct_total[:, 0], 'r--', label='N1 Direct')
axs[0].plot(t_total, pred_direct_total[:, 1], 'g--', label='N2 Direct')
axs[0].plot(t_total, pred_direct_total[:, 2], 'b--', label='N3 Direct')
axs[0].scatter(t[indices], N1[indices], c='k', s=10)
axs[0].scatter(t[indices], N2[indices], c='k', s=10)
axs[0].scatter(t[indices], N3[indices], c='k', s=10, label='Collocation')
axs[0].set_xlim([t_start, t_end + prediction_time])
axs[0].set_title(f"Direct ANN | L = {L_direct_total:.2e}, L_MSE = {L_direct_mse:.2e}, Extrap Err = {error_direct:.2e}")
axs[0].legend()
axs[0].grid(True)

# Bottom: PINN
axs[1].plot(t_total, N1_true_total, 'r', label='N1 True')
axs[1].plot(t_total, N2_true_total, 'g', label='N2 True')
axs[1].plot(t_total, N3_true_total, 'b', label='N3 True')
axs[1].plot(t_total, pred_pinn_total[:, 0], 'r--', label='N1 PINN')
axs[1].plot(t_total, pred_pinn_total[:, 1], 'g--', label='N2 PINN')
axs[1].plot(t_total, pred_pinn_total[:, 2], 'b--', label='N3 PINN')
axs[1].scatter(t[indices], N1[indices], c='k', s=10)
axs[1].scatter(t[indices], N2[indices], c='k', s=10)
axs[1].scatter(t[indices], N3[indices], c='k', s=10, label='Collocation')
axs[1].set_xlim([t_start, t_end + prediction_time])
axs[1].set_title(f"PINN | L = {L_pinn_total:.2e}, L_MSE = {L_pinn_mse:.2e}, L_ODE = {L_pinn_ode:.2e}, Extrap Err = {error_pinn:.2e}")
axs[1].legend()
axs[1].grid(True)

plt.xlabel("Time")
plt.tight_layout()
plt.savefig('Radioactive-decay_PINN.png', dpi=300)
plt.show()
